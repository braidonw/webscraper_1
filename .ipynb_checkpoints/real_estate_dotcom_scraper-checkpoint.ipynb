# %%
import requests
from bs4 import BeautifulSoup
import re
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://scraper:scraper1!@ds247270.mlab.com:47270/webscrape')
db = client.get_database()

# %%
w = requests.get('https://www.realestate.com.au/rent/in-wolli+creek%2c+nsw+2205%3b+/list-1?includeSurrounding=false')

# %%
# Config
base_url='https://www.realestate.com.au'
first_page='/rent/in-wolli+creek%2c+nsw+2205%3b+/list-1?includeSurrounding=false'

# %%
def get_next_page_url(soup):
    try:
        next_page = soup.find('li',{'class':'nextLink'}).find('a',href=True)['href']
        next_page_url = (base_url+next_page).replace(",", "%2c")
        return(next_page_url)
    except:
        pass

# %%
def scrape_listings(s):
    #init blank list for output variable
    scraped_listings = []
    
    listings = s.find_all('article', {'class':'resultBody'})
    
    for item in listings:
        d = {}

        #get the physical address
        try:
            d['address'] = item.find('a',{'class':'name','rel':'listingName'}).text
        except:
            print('None')

        #get the URL
        d['link']=item.find('a', href=True)['href']

        # get price data
        try:
            price_text = item.find('p',{'class':'priceText'}).text
        
            try:
                d['price']=(re.findall(r"\d+",price_text)[0])
            except:
                d['price']=("NA - Deposit Taken")
        
        except:
            price_text = None

        # get the property features (simple ones only)
        features = item.find('dl',{'class':'rui-property-features'})
        for feature_name, feature_count in zip(
            features.find_all('dt',{'class':'rui-icon'}),
            features.find_all('dd')
        ):
            d[feature_name.text.lower()] = feature_count.text.lower()
        scraped_listings.append(d)
        
    return scraped_listings

# %%
output_list = []

#set up first page to scrape
page_url = (base_url + first_page)
print(page_url)
while page_url is not None:
    soup = BeautifulSoup(requests.get(page_url).content, 'html.parser')
    output = scrape_listings(soup)
    output_list.extend(output)
    page_url = get_next_page_url(soup)
    
    print(page_url)
# Out:
# https://www.realestate.com.au/rent/in-wolli+creek%2c+nsw+2205%3b+/list-1?includeSurrounding=false
# https://www.realestate.com.au/rent/in-wolli+creek%2c+nsw+2205/list-2?includeSurrounding=false
# https://www.realestate.com.au/rent/in-wolli+creek%2c+nsw+2205/list-3?includeSurrounding=false
# https://www.realestate.com.au/rent/in-wolli+creek%2c+nsw+2205/list-4?includeSurrounding=false
# https://www.realestate.com.au/rent/in-wolli+creek%2c+nsw+2205/list-5?includeSurrounding=false
# https://www.realestate.com.au/rent/in-wolli+creek%2c+nsw+2205/list-6?includeSurrounding=false
# https://www.realestate.com.au/rent/in-wolli+creek%2c+nsw+2205/list-7?includeSurrounding=false
# https://www.realestate.com.au/rent/in-wolli+creek%2c+nsw+2205/list-8?includeSurrounding=false
# None

# %%
output_list
# Out:
# [{'address': '605/26-32 Marsh Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-407924983',
#   'price': '480',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'BG07/24 Levey Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424796790',
#   'price': '560',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '802/26-32 Marsh Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-408016979',
#   'price': '770',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': '1002/6-10 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424561302',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'C1503/10 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424668462',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '1102/35A Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424771750',
#   'price': '800',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '501/2 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424753462',
#   'price': '500',
#   'bedrooms': '1',
#   'bathrooms': '1'},
#  {'address': '205/6 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424630598',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '309/5 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424629570',
#   'price': '680',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '707/6 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424620050',
#   'price': '670',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424703842',
#   'price': '700',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424703850',
#   'price': '930',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': '907/10 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424697810',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '93/15-23 Lusty Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-416029573',
#   'price': '925',
#   'bedrooms': '3',
#   'bathrooms': '1',
#   'car spaces': '2'},
#  {'address': 'C1501/6-10 Gertrude Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424752598',
#   'price': '680',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '503/6  Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424734538',
#   'price': '695',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'D313/35 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424731486',
#   'price': '595',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '804/20 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-unit-nsw-wolli+creek-424692722',
#   'price': '720',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '2 Willis Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424461202',
#   'price': '930',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '25/15-23 Lusty Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424705150',
#   'price': '780',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': '503/10 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424667706',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '207/6 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424660218',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '21/5 Lusty Street, Wolli Creek, NSW 2205',
#   'link': '/property-unit-nsw-wolli+creek-417440042',
#   'price': '480',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '608/15 Brodie Sparks Drive, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424607442',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'C1105/10 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424600406',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '401/15 Brodie Spark drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424594302',
#   'price': '550',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'A204/40-50 Arncliffe St, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424744126',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B602/40-50 Arncliffe St, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424715950',
#   'price': '640',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'Level 8/10 Gertrude Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424517442',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '6-10  Gertrude St, Wolli Creek, NSW 2205',
#   'link': '/property-unit-nsw-wolli+creek-424481070',
#   'price': '530',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424450566',
#   'price': '700',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '1408/26 Levey st, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-423701870',
#   'price': '900',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': 'D112/35 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-402208995',
#   'price': '540',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '9 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424799234',
#   'price': '560',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '40-50 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424798986',
#   'price': '550',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '501/16 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424797334',
#   'price': '690',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '40-50 Arncliffe St, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424794230',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '16/5 Lusty Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424792294',
#   'price': '495',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'A501/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424792190',
#   'price': '670',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'L9/20 Chisholm Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424792082',
#   'price': '740',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '203b/20-26 Innesdale Road, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424792074',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'B409/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424791858',
#   'price': '670',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '9 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424790966',
#   'price': '750',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '9 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424790722',
#   'price': '640',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B406/40-50 Arncliffe st, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424789978',
#   'price': '780',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '50 Arncliffe, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424789050',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '209/52 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424788226',
#   'price': '620',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'L2/2 Discovery Point Place, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424787414',
#   'price': '520',
#   'bedrooms': '1',
#   'bathrooms': '1'},
#  {'address': 'L7/2  Chisholm Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424787322',
#   'price': '680',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'L13/2 Chisholm Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424787190',
#   'price': '720',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'LG/15  Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424786506',
#   'price': '640',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '601/6 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424785222',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '1608/1 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-419144674',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'L3/15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424784022',
#   'price': '550',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '602/8 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424783982',
#   'price': '700',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'L3/15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424783974',
#   'price': '500',
#   'bedrooms': '1',
#   'bathrooms': '1'},
#  {'address': '28-30 Ann Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424783134',
#   'price': '475',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '103/15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424779330',
#   'price': '640',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '305/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424778306',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'AG08/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424778234',
#   'price': '630',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'AG07/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424778134',
#   'price': '630',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'BG06/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424777906',
#   'price': '470',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'BG02/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424777858',
#   'price': '500',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B604/40-50  Arncliffe Rd, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424774766',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B605/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424772682',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '40-50   Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424771938',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A102/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424771882',
#   'price': '610',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'C12.01/6-10 Gertrude Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424768394',
#   'price': '800',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'L2/7 Magdalene Terrace, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424767330',
#   'price': '640',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '615/52-62 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424763530',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'L4/1 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424760874',
#   'price': '550',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '1105/26 Levey St, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424759906',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '48-50 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424758986',
#   'price': '630',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'b903/35 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424752418',
#   'price': '680',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A503/20 Levey Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424752406',
#   'price': '670',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'L13/7 Magdalene Terrace, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424751050',
#   'price': '970',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': '5/15-23 Lusty St, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424747466',
#   'price': '620',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '40-50 Arncliffe, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424745178',
#   'price': '500',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '905/35A Arncliffe Road, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-416740117',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B606/40-50 Arncliffe Road, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424744426',
#   'price': '790',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'L6/16 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424743166',
#   'price': '690',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'L6/7 Magdalene Terrace, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424742674',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '89/1-5 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424739814',
#   'price': '620',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A706/8 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424739754',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': '145/97 Bonar Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424737566',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '255/16 Lusty Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424731350',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A808/6 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424731210',
#   'price': '530',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '1106/10 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424730994',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '66/95 Bonar Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424716150',
#   'price': '930',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': 'a206/40 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424716146',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '104/1 Magdalene Terrace, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424712970',
#   'price': '660',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B506/40 Arncliffe St, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424710470',
#   'price': '650',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'B209/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424697730',
#   'price': '630',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A309/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424697486',
#   'price': '630',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '901/36-42 Levey Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424696246',
#   'price': '640',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '97 Bonar Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424695462',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'Unit 104/26 Levey Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424694614',
#   'price': '680',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'B402/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424690230',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'C903/26 Levey Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424688242',
#   'price': '550',
#   'bedrooms': '1',
#   'bathrooms': '1'},
#  {'address': '701/10 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424676062',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '106/26-32 Marsh Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-418024942',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A410/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424670182',
#   'price': '620',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A102/40-50  Arncliffe Street, Wolli Creek,...',
#   'link': '/property-apartment-nsw-wolli+creek-424669438',
#   'price': '610',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A116/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424668994',
#   'price': '520',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B504/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424668498',
#   'price': '580',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'A111/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-unit-nsw-wolli+creek-424666206',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A215/40-50 Arncliffe St, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424664770',
#   'price': '510',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'Level 6/8 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424656570',
#   'price': '860',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': '117/97 Bonar Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-420440990',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A510/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424652738',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A409/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424652726',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A106/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424652706',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'B705/8 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424646746',
#   'price': '690',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'L4/15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424641738',
#   'price': '700',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'L5/15 Brodie spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424641718',
#   'price': '950',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': 'B503/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424641510',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'AG01/40-50 Arncliffe St, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424640982',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '40-50 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424631170',
#   'price': '610',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A307/6 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424630974',
#   'price': '530',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'C301/6 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424630858',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'BG07/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424628586',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B202/40 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424626842',
#   'price': '620',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '212/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424596558',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'A1902/35 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424580278',
#   'price': '700',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '40-50  Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424580166',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '40-50 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424579898',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '4/20-22  Princes Hwy, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424578914',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': '811/20 Chilsholm, Wolli Creek, NSW 2205',
#   'link': '/property-unit-nsw-wolli+creek-424572478',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1'},
#  {'address': '1BED/6 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424565606',
#   'price': '530',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B501/8 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424561370',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '104/20-26 Innesdale Rd, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-419095650',
#   'price': '610',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '1107/10 Gertrude street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424561262',
#   'price': '680',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '2-6 Willis Street, Wolli Creek, NSW 2205',
#   'link': '/property-unit-nsw-wolli+creek-424553598',
#   'price': '680',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '40-50 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424541126',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'B205/40-50 Arncliffe Street, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-424538906',
#   'price': '580',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '806/26-32 Marsh Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424534850',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424532982',
#   'price': '800',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '40 Arncliffe Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424532582',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '1/23 Ann Street, Wolli Creek, NSW 2205',
#   'link': '/property-unit-nsw-wolli+creek-420532186',
#   'price': '495',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '602/26 Marsh Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-417555262',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '2'},
#  {'address': '101/15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424496882',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '601/8 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424495986',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '1309/1 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424480462',
#   'price': '640',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '2-6  Willis Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424473070',
#   'price': '530',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '1211/17 Chisholm Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424446506',
#   'price': '750',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': 'A202/6 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424417306',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '146/88 Bonar  Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424408426',
#   'price': '610',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '912/17 Chisholm St, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424361814',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '410/17 Chisholm Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424353630',
#   'price': '545',
#   'bedrooms': '1',
#   'bathrooms': '1'},
#  {'address': '106/10 Gertrude Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-424116502',
#   'price': '650',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '50/5 Lusty Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-420904146',
#   'price': '490',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'Wolli Creek, address available on request',
#   'link': '/property-apartment-nsw-wolli+creek-423922250',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'G02/15 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-423920122',
#   'price': '630',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': 'B302/8 Gertrude Avenue, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-423871682',
#   'price': '690',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '91./97 Bonar Street, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-423585726',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '1004/5 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-423372958',
#   'price': 'NA - Deposit Taken',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '401/16  Brodie Spark Drive, Wolli Creek, NSW...',
#   'link': '/property-apartment-nsw-wolli+creek-423216814',
#   'price': '780',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '1'},
#  {'address': '511/1 Brodie Spark Drive, Wolli Creek, NSW 2205',
#   'link': '/property-apartment-nsw-wolli+creek-423130170',
#   'price': '600',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car spaces': '1'},
#  {'address': '32/5 Lusty Street, Wolli Creek, NSW 2205',
#   'link': '/property-unit-nsw-wolli+creek-423009334',
#   'price': '600',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car spaces': '2'}]

# %%
listing = output_list[0]
listing_url = base_url + listing['link']
c = requests.get(listing_url).content
soup = BeautifulSoup(c, 'html.parser')
descriptions = soup.find_all('p', {'class':'body'})
#listing['description'] 
descriptions
#listing['general_features'] = soup.findall('li', {''})
# Out:
# [<p class="body">Brilliant 1 Bedroom Apartment, Please call Chloe 0410 065 050 for inspection. <br/><br/><br/>Please call Chloe 0410 065 050<br/> for inspection appointment~<br/>The stylish new apartments are designed for modern living and comfort. Relax and enjoy panoramic water and golf course views; take an easy stroll to Kogarah golf course and be only minutes to the CBD and M5 motorway. Close to Sydney international and domestic airports.<br/><br/>Features includes: Gourmet kitchens, European Stainless steel appliances with gas cooking &amp; dishwasher, Separate laundries with dryer, Built-in wardrobes and plentiful storage, Secure parking with remote control access and intercom, ample provision for visitor parking, common entertaining and bbq area….</p>]
